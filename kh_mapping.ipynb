# %%
import pandas as pd

import os
import configparser
import datetime as dt
from datetime import datetime
from os.path import exists
import time

import folium
from random import randint

import shapely
from shapely.geometry import Point, Polygon, LineString, GeometryCollection
import numpy as np

# %%
# Method to read config file settings
def read_config(Config_File):
    config = configparser.ConfigParser()
    config.read(Config_File)
    return config

configurations = read_config("configurations.ini")

# %%
# Function to merge csv feed files
def merge_transitview_rt(start_date_time_str, stop_date_time_str):
    start_date_time = datetime.strptime(start_date_time_str, '%m/%d/%Y %H:%M')
    stop_date_time = datetime.strptime(stop_date_time_str, '%m/%d/%Y %H:%M')
    
    start = time.time()
    f_count = 0
    
    # delta time
    delta = dt.timedelta(minutes=1)
    
    csv_list = []
    print('reading in CSVs')
    # iterate over range of date / time
    while (start_date_time <= stop_date_time):

        #generate the file name to open
        folder = configurations['common_settings']['transitviewall_history_data_root'] + "\\" \
            + start_date_time.strftime("%#m") + '\\' \
            + start_date_time.strftime("%#d") + '\\' \
            + start_date_time.strftime("%H") + '\\' \
            + start_date_time.strftime("%M") + '\\' 
        
        file = folder + 'feed.csv'

        if exists(file):
            csv_list.append(pd.read_csv(file))
            
        f_count +=1
        end = time.time()
        print(str(f_count) + '. ' + str(round(end-start,0)) + 'sec --- file: ' + str(start_date_time), flush=True, end='\r')
            
        # increemnt datetime by 1 minute
        start_date_time += delta
    
    print('\nmerging into single data frame')
    csv_merged = pd.concat(csv_list, ignore_index=True)
    print(str(round(time.time()-start,0))+'sec')
    
    indexDrop = csv_merged[(csv_merged['late'] == 998) | (csv_merged['late'] == 999)].index
    csv_merged.drop(indexDrop , inplace=True)
    
    print('exporting to single CSV file')
    csv_merged.to_csv('data\kh_transitview.csv', index=False)
    print(str(round(time.time()-start,0))+'sec')

# %%
merge_transitview_rt("7/26/2022 00:00", "7/31/2022 23:59")
# Out:
# reading in CSVs
# 8640. 195.0sec --- file: 2022-07-31 23:59:00
# merging into single data frame
# 217.0sec
# exporting to single CSV file
# 341.0sec

# %%
# LOAD NEEDED DATA

# %%
# Load RT data (gtfs_data)

# %%
gtfs_data = pd.read_csv('data\kh_transitview.csv')
gtfs_data['file'] = pd.to_datetime(gtfs_data['file'])
gtfs_data['timestamp'] = pd.to_datetime(gtfs_data['timestamp'])
gtfs_data.head(5)
# Out:
#    BlockID   Direction  Offset  Offset_sec  VehicleID  \
# 0     1076  NorthBound       1          19       7452
# 1     1077  SouthBound       1          13       7444
# 2     1078  NorthBound       1           8       7447
# 3     1120  SouthBound       1          33       8664
# 4     1221   EastBound       1          28       8184
#
#                        destination estimated_seat_availability       file  \
# 0                   Neshaminy Mall               NOT_AVAILABLE 2022-07-26
# 1  Frankford Transportation Center               NOT_AVAILABLE 2022-07-26
# 2                   Neshaminy Mall               NOT_AVAILABLE 2022-07-26
# 3  Frankford Transportation Center               NOT_AVAILABLE 2022-07-26
# 4               Torresdale-Cottman               NOT_AVAILABLE 2022-07-26
#
#    heading  label        lat  late        lng  next_stop_id  \
# 0      360   7452  40.024891     0 -75.077209       21962.0
# 1      225   7444  40.112644     8 -74.990776       22765.0
# 2       45   7447  40.110142     2 -74.993507       22537.0
# 3      195   8664  40.040073     2 -75.059570          22.0
# 4      120   8184  40.054508     0 -75.071701       21268.0
#
#                                    next_stop_name  next_stop_sequence  \
# 0  Frankford Transportation Center-14-BLVDDIR-MFO                 1.0
# 1               Roosevelt Blvd & Southampton - FS                54.0
# 2                    Roosevelt Blvd & Haldeman Av                40.0
# 3                     Roosevelt Blvd & Cottman Av                 9.0
# 4                        Cottman Av & Whitaker Av                46.0
#
#    original_late    route                 timestamp  trip
# 0              0       14 2022-07-26 04:00:04+00:00  6644
# 1              8       14 2022-07-26 04:00:04+00:00  6756
# 2              2       14 2022-07-26 04:00:04+00:00  6643
# 3              2  BLVDDIR 2022-07-26 04:00:04+00:00  7920
# 4              1       70 2022-07-26 04:00:04+00:00  7573

# %%
# Load Schedule Trips Data (trips_data)

# %%
sched_folder = configurations['common_settings']['schedule_root']
trips_f = sched_folder + '\\' + 'trips.txt'
trips_data = pd.read_csv(trips_f)
trips_data.head()
# Out:
#   route_id  service_id  trip_id                     trip_headsign  block_id  \
# 0        1          10     6545                  Decatur-Drummond      1003
# 1        1          10     6546                       Parx Casino      2151
# 2        1          10     6547  Parx Casino via Decatur-Drummond      2156
# 3        1          10     6548                  Decatur-Drummond      1426
# 4        1          10     6549  Parx Casino via Decatur-Drummond      2154
#
#    direction_id  shape_id
# 0             0    272448
# 1             0    272446
# 2             0    272453
# 3             0    272452
# 4             0    272453

# %%
# Load Schedule Shapes Data (shapes_data)

# %%
shapes_f = sched_folder + '\\' + 'shapes.txt'
shapes_data = pd.read_csv(shapes_f)
shapes_data.head()
# Out:
#    shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence
# 0    272882     39.932162    -75.149143                707
# 1    272882     39.928007    -75.150762                727
# 2    272882     39.914772    -75.155033                759
# 3    272882     39.912738    -75.139676                790
# 4    272880     39.986990    -75.137130                358

# %%
###### MAPPING

# %%
## Plot Schedule shapes

# %%
shape_1 = shapes_data.loc[shapes_data['shape_id'] == 272882]
shape_1 = shape_1.sort_values(by=['shape_pt_sequence'])

shape_2 = shapes_data.loc[shapes_data['shape_id'] == 272880]
shape_2 = shape_2.sort_values(by=['shape_pt_sequence'])

# %%
s1 = list(zip(shape_1.shape_pt_lat, shape_1.shape_pt_lon))
s2 = list(zip(shape_2.shape_pt_lat, shape_2.shape_pt_lon))

# %%
map = folium.Map(location=[40,-75.154839], zoom_start= 11)

folium.PolyLine(s1, color='red', weight=10, opacity=0.8).add_to(map)
folium.PolyLine(s2, color='blue', weight=10, opacity=0.8).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f260647d65eeeac86a61065daab7839 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f260647d65eeeac86a61065daab7839&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8f260647d65eeeac86a61065daab7839 = L.map(
#                 &quot;map_8f260647d65eeeac86a61065daab7839&quot;,
#                 {
#                     center: [40.0, -75.154839],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_
041412, -75.120105], [40.040906, -75.12022], [40.040434, -75.120319], [40.039924, -75.120427], [40.038408, -75.12074], [40.03785, -75.120854], [40.036856, -75.121077], [40.035947, -75.12128], [40.035278, -75.121415], [40.035278, -75.121415], [40.035142, -75.120257], [40.035123, -75.120106], [40.035098, -75.119916], [40.035074, -75.119745], [40.035047, -75.119542], [40.034863, -75.118134], [40.034794, -75.117555], [40.034696, -75.116834], [40.034615, -75.116156], [40.034561, -75.115695], [40.034528, -75.115462], [40.034483, -75.115072], [40.034462, -75.114954], [40.034122, -75.1152], [40.03376, -75.11549], [40.033046, -75.116081], [40.032064, -75.116924], [40.031631, -75.117283], [40.030539, -75.118197], [40.030227, -75.118455], [40.029522, -75.119041], [40.028844, -75.119596], [40.028327, -75.120023], [40.027682, -75.120565], [40.027471, -75.120728], [40.027097, -75.121031], [40.026883, -75.121212], [40.026264, -75.121732], [40.026142, -75.121839], [40.026, -75.121963], [40.025887, -75.122064], [40.025649, -75.122261], [40.025512, -75.122385], [40.025228, -75.122633], [40.02475, -75.123039], [40.024577, -75.123187 ...

# %%
# Plot all trip schedule shapes for a given route

# %%
route_47_trips = trips_data.loc[trips_data['route_id'] == '47']
route_47_trips = route_47_trips['shape_id'].unique().tolist()
route_47_trips.sort()

# %%
map = folium.Map(location=[40,-75.154839], zoom_start= 11)

n = len(route_47_trips)
color = []
# create an n long random list of colors
for i in range(n):
    color.append('#%06X' % randint(0, 0xFFFFFF))

for shape_id, c in zip(route_47_trips, color):
    shape = shapes_data.loc[shapes_data['shape_id'] == shape_id]
    shape = shape.sort_values(by=['shape_pt_sequence'])
    shape = list(zip(shape.shape_pt_lat, shape.shape_pt_lon))
    
    folium.PolyLine(shape, color = c, popup = shape_id, weight=7, opacity=0.6).add_to(map) 

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78d390a71614b538955f5009de62f00a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78d390a71614b538955f5009de62f00a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_78d390a71614b538955f5009de62f00a = L.map(
#                 &quot;map_78d390a71614b538955f5009de62f00a&quot;,
#                 {
#                     center: [40.0, -75.154839],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9db06b2c0d156654628efd50134e3c33 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_78d390a71614b538955f5009de62f00a);
#
#
#             var poly_line_c1c66eeee0377368ce27e4a297032dda = L.polyline(
#                 [[40.046246, -75.128069], [40.046058, -75.1284], [40.045645, -75.128485], [40.045309, -75.128558], [40.044849, -75.128658], [40.044275, -75.128786], [40.044086, -75.128828], [40.043579, -75.128937], [40.043121, -75.129037], [40.042577, -75.129156], [40.04183, -75.12932], [40.041052, -75.129488], [40.039531, -75.129826], [40.037985, -75.130167], [40.036438, -75.130507], [40.034746, -75.130873], [40.03339, -75.131179], [40.032869, -75.131299], [40.032334, -75.131413], [40.031873, -75.131503], [40.031352, -75.131613], [40.030332, -75.131845], [40.029638, -75.131993], [40.029254, -75.132075], [40.028791, -75.132182], [40.028451, -75.132246], [40.02802, -75.132342], [40.02727, -75.1325], [40.025787, -75.132824], [40.024999, -75.133006], [40.024299, -75.133
# %%
# Function to return schedule shape of a trip_id
def get_shape(trip):
    shape_id = trips_data.loc[trips_data['trip_id'] == trip]
    
    shape = shapes_data.loc[shapes_data['shape_id'] == shape_id.iloc[0]['shape_id']]
    shape = shape.sort_values(by=['shape_pt_sequence'])
    shape_coord = list(zip(shape.shape_pt_lat, shape.shape_pt_lon))
    
    return shape_coord

# %%
# compare RT to scheduled route
gtfs_rt_47 = gtfs_data.loc[(gtfs_data['route'] == '47') & (gtfs_data['file'] >= '2022-07-26 00:00:00') & (gtfs_data['file'] <= '2022-07-26 23:59:00')]

# %%
rt_47_trips = gtfs_rt_47['trip'].unique().tolist()
rt_47_trips.sort()

# %%
map = folium.Map(location=[40,-75.154839], zoom_start= 11)

#select only 1 trip_id of those for route 47
trip = rt_47_trips[0]

polyl = gtfs_rt_47.loc[gtfs_rt_47['trip'] == trip]
polyl = polyl.sort_values(by=['file'])
polyl = list(zip(polyl.lat, polyl.lng))
  
folium.PolyLine(polyl, color = 'red', popup = 'RT', weight=7, opacity=0.6).add_to(map) 

shape = get_shape(trip)
  
folium.PolyLine(shape, color = 'blue', popup = 'Sched', weight=7, opacity=0.6).add_to(map) 

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3089f4542dc0a4c7dbc1e0d349ad4977 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3089f4542dc0a4c7dbc1e0d349ad4977&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3089f4542dc0a4c7dbc1e0d349ad4977 = L.map(
#                 &quot;map_3089f4542dc0a4c7dbc1e0d349ad4977&quot;,
#                 {
#                     center: [40.0, -75.154839],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2c52c58a3c8325a1549ff84858d888e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3089f4542dc0a4c7dbc1e0d349ad4977);
#
#
#             var poly_line_eccdfbb216c8b4ec8b557017f9d58fa8 = L.polyline(
#                 [[40.046013, -75.12773099999998], [40.046013, -75.12773099999998], [40.04604, -75.12773099999998], [40.046314, -75.12805199999998], [40.044254, -75.128799], [40.039768, -75.129799], [40.036884, -75.130402], [40.035755, -75.130646], [40.031078, -75.13168299999998], [40.029018, -75.132141], [40.025967, -75.132851], [40.025993, -75.13281999999998], [40.025993, -75.132851], [40.025414, -75.13292699999998], [40.024616, -75.13310199999998], [40.023022, -75.13346099999998], [40.022388, -75.130615], [40.021622, -75.12603], [40.016644, -75.128906], [40.01469, -75.131607], [40.013729, -75.13548299999998], [40.012241, -75.13580299999998], [40.010868, -75.136086], [40.009106, -75.13807699999998], [40.008064, -75.13871799999998], [40.004761, -75.139435], [40.002258, -75.139999], [40.000198, -75.140465], [39.997089, -75.14110599999998], [39.995304, -75.141495], [39.992802, -75.14202899999998], [39.990959, -75.142418], [39.988869, -75.142914], [39.985649, -75.14359299999998], [39.984936, -75.145187], [39.984467, -75.146866], [39.982159, -75.14739199999998], [39.979107, -75.148033], [39.976051, -75.148712], [39.973412, -75.149277], [39.972012, -75.149246], [39.970634, -75.148926], [39.968491, -75.150345], [39.966869, -75.15070299999998], [39.96376, -75.151375], [39.961861, -75.151695], [39.961834, -75.151695], [39.958508, -75.15198499999998], [39.958534, -75.15198499999998], [39.9576, -75.15209199999998], [39.955921, -75.15255], [39.954273, -75.15290799999998], [39.952293, -75.15333599999998], [39.951576, -75.15358], [39.949902, -75.15379299999998], [39.949902, -75.153763], [39.948498, -75.154083], [39.947178, -75.15432699999998], [39.945858, -75.15461], [39.945858, -75.15461], [39.943466, -75.155144], [39.940853, -75.155754], [39.93824, -75.15631899999998], [39.93615, -75.156784], [39.934582, -75.157104], [39.931721, -75.157745], [39.929054, -75.158348], [39.925701, -75.159096], [39.923031, -75.158989], [39.922508, -75.15486099999998], [39.919868, -75.15389999999998], [39.916183, -75.154686], [39.914783, -75.155968], [39.912418, -75.15546399999998], [39.91217, -75.153259], [39.91217, -75.15329699999998], [39.91217, -75.15329699999998], [39.91217, -75.15329699999998], [39.91217, -75.15329699999998], [39.912197, -75.15333599999998], [39.91217, -75.15329699999998], [39.91217, -75.15329699999998], [39.91217, -75.15329699999998], [39.91217, -75.15329699999998], [39.91217, -75.15329699999998], [39.91217, -75.15329699999998], [39.91217, -75.15329699999998], [39.912224, -75.15387], [39.913574, -75.15518199999998], [39.914398, -75.155968]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_3089f4542dc0a4c7dbc1e0d349ad4977);
#
#
#         var popup_e9006c87cf5f28a38f14ac2edc5cadcc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a7bf56b7f0ee8d8ef78294771a6cdd86 = $(`&lt;div id=&quot;html_a7bf56b7f0ee8d8ef78294771a6cdd86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RT&lt;/div&gt;`)[0];
#             popup_e9006c87cf5f28a38f14ac2edc5cadcc.setContent(html_a7bf56b7f0ee8d8ef78294771a6cdd86);
#
#
#         poly_line_eccdfbb216c8b4ec8b557017f9d58fa8.bindPopup(popup_e9006c87cf5f28a38f14ac2edc5cadcc)
#         ;
#
#
#
#
#             var poly_line_fb6821d148059c3899825923137fc53c = L.polyline(
#                 [[40.046246, -75.128069], [40.046058, -75.1284], [40.045645, -75.128485], [40.045309, -75.128558], [40.044849, -75.128658], [40.044275, -75.128786], [40.044086, -75.128828], [40.043579, -75.128937], [40.043121, -75.129037], [40.042577, -75.129156], [40.04183, -75.12932], [40.041052, -75.129488], [40.039531, -75.129826], [40.037985, -75.130167], [40.036438,

# %%
# going through all RT points and finding Max deviation (maximum min distance)
sch = LineString(shape)

max_dist = 0

for pol in polyl:
    pt = Point(pol)
    dist = pt.distance(sch)
    if dist > max_dist:
        max_dist = dist
 
print(max_dist)
# Out:
# 0.007551171871767615

# %%
#Find next bus and track it and determine if it went on a detour

# %%
# Input
now_date = '7/26/2022'
now_time = '07:30'
now_file = datetime.strptime(now_date + ' ' + now_time, '%m/%d/%Y %H:%M')
route = '47'
direction = 'SouthBound'
my_stop_seq = 40

# %%
# All current buses (in current feed file) that have not yet passed my stop
gtfs_rt = gtfs_data.loc[(gtfs_data['file'] == now_file) & (gtfs_data['route'] == route) &\
                        (gtfs_data['Direction'] == direction) & (gtfs_data['next_stop_sequence'] <= my_stop_seq)]

gtfs_rt = gtfs_rt.sort_values(by = ['next_stop_sequence'])

# %%
# return location of a trip at a given time (feed file name)
def now_loc(now, trip):
    data = gtfs_data.loc[(gtfs_data['file'] == now) & (gtfs_data['trip'] == trip)]
    if data.empty:
        return 'NOT FOUND'
    else:
        return (data['lat'].iat[0], data['lng'].iat[0])

# %%
# Pick closest bus and track it
next_trip_id = gtfs_rt['trip'].iat[-1]
next_trip_shape = get_shape(next_trip_id)

now = now_file

ln = LineString(next_trip_shape)
location = now_loc(now, next_trip_id)
delta = dt.timedelta(minutes=1)

# %%
# each time this block is run the bus moves 1 minute

# check if there is a previous detour
max_prev_dist = 0
for pt in rt_shape:
    pt = Point(pt)
    dist = pt.distance(ln)
    if dist > max_prev_dist:
        max_prev_dist = dist
        

if max_prev_dist >= 0.003:
    print('BUS HAS DETOURED --- Max deviation distance = ' + str(max_prev_dist))
else: 
    print('BUS NEVER DETOURED --- Max deviation distance = '  + str(max_prev_dist))

      
pt = Point(location)
now_dist = pt.distance(ln)

if now_dist >= 0.003:
    print('BUS STILL ON DETOUR --- Current deviation distance = ' + str(dist))
else: 
    print('BUS CURRENTLY ON ROUTE --- Current distance from route = '  + str(dist))
    
rt_shape = gtfs_rt_47.loc[(gtfs_rt_47['trip'] == next_trip_id) & (gtfs_rt_47['file'] <= now)]
rt_shape = rt_shape.sort_values(by=['file'])
rt_shape = list(zip(rt_shape.lat, rt_shape.lng))


map = folium.Map(location=[40,-75.154839], zoom_start= 12)

folium.PolyLine(rt_shape, color = 'blue', weight=7, opacity=0.6).add_to(map) 
folium.PolyLine(next_trip_shape, color = 'red', weight=7, opacity=0.6).add_to(map) 
folium.Marker(location, icon=folium.Icon(color='blue', icon='bus', prefix='fa'), popup = 'Trip_ID = '+ str(next_trip_id)).add_to(map)

now += delta
location = now_loc(now, next_trip_id)

map
# Out:
# BUS HAS DETOURED --- Max deviation distance = 0.007370346057017579
# BUS CURRENTLY ON ROUTE --- Current distance from route = 3.160023513856936e-05
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7156c8db19b3f3171ecf6e99d18df88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7156c8db19b3f3171ecf6e99d18df88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f7156c8db19b3f3171ecf6e99d18df88 = L.map(
#                 &quot;map_f7156c8db19b3f3171ecf6e99d18df88&quot;,
#                 {
#                     center: [40.0, -75.154839],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d538d83b500561fde240a6899736ba57 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f7156c8db19b3f3171ecf6e99d18df88);
#
#
#             var poly_line_543cf349710a26aebc7f9ded43bde5c5 = L.polyline(
#                 [[40.044308, -75.128731], [40.041557, -75.129333], [40.038174, -75.130081], [40.03537, -75.130722], [40.032097, -75.131393], [40.030449, -75.13178999999998], [40.025745, -75.13281999999998], [40.023682, -75.13324699999998], [40.022694, -75.13346099999998]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: